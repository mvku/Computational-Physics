# %%
ddir = 'C:/Users/vijay/Downloads/'
import numpy as np
from numpy import *
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from matplotlib.colors import Normalize
import collections
from itertools import groupby
# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
import matplotlib.cm as cm
import matplotlib.mlab as mlab
from pylab import figure, axes, pie, title, show
from scipy.signal import find_peaks
from scipy.interpolate import interp1d
# %matplotlib notebook


plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["mathtext.fontset"] = 'cm'
plt.rcParams["axes.labelsize"] = '13'
plt.rcParams['xtick.major.size'] = '3'
plt.rcParams['grid.alpha'] = '0.5'
plt.rcParams['legend.fontsize'] = '11'
plt.rcParams['errorbar.capsize'] = '2.5'
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['xtick.labelsize'] = '12'
plt.rcParams['ytick.labelsize'] = '12'
plt.rcParams['text.usetex'] = False #True

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
shapes = ['o', 'X', 's', 'd', 'v', '^']

# %%
A = np.loadtxt (ddir+'Data1.txt')
B = np.loadtxt (ddir+'Data2.txt')
#df = pd.read_csv(ddir+'Data.csv')

# %%
x=A[:,0]
y=A[:,1]
z=A[:,2]
u=B[:,0]/1000
v=B[:,1]/1e-19                                                              

def line(x,a):
    return a*np.sqrt(x)
xnew=np.linspace(0.0,6.0,200)                                                               
popt, pcov = curve_fit(line, x, y)
pfit = line(xnew,*popt)

# %%
yerr=y
upperlimits=150
lowerlimits=150

# %%
fig,ax=plt.subplots(2,figsize=(8,8))
ax[0].plot(x,y,'ob',markersize='12')
ax[0].plot(xnew,pfit,'-r')
#ax[0].errorbar(x, y, yerr, uplims=upperlimits, lolims=lowerlimits,label='subsets of uplims and lolims')
ax[0].set_xlim(0,5.5)
ax[0].set_ylim(0,600)

ax[0].set_xlabel(r'$V_{RF}$')
ax[0].set_ylabel(r'$\Delta f_{SB1}(Hz)$')
plt.text(187,2800,r'$\Delta f_{SB1}[Hz]=242\sqrt{V_{RF}(V)}$')#, bbox=dict(facecolor='white', alpha=0.5))


ax[1].plot(u,v,'-k')
ax[1].axvline(x=187.79,linestyle='--')
#ax[1].axhline(y=33.3,linestyle='--',color='r')

ax[1].axvline(x=187.420,linestyle='--')
ax[1].axvline(x=188.15998,linestyle='--')

ax[1].axvline(x=187.0403,linestyle='--')
ax[1].axvline(x=188.5393,linestyle='--')

ax[1].axvline(x=186.67,linestyle='--')
ax[1].axvline(x=188.89,linestyle='--')
ax[1].set_xlim(186.5,189)
ax[1].set_ylim(-250,1300)


ax[1].set_xlabel(r'$f(kHz)$')
ax[1].set_ylabel(r'$I(f)-(arb.units)$')

#ax[1].arrow(186.67,33,188,33,width=1,length_includes_head=1,head_width=1,head_length=1)
#ax[1].annotate('double-headed arrow', xy=(187,189), xytext=(0.01,0.5),
            #arrowprops={'arrowstyle': '<->'}, va='center')
ax[1].annotate(s='', xy=(186.65,-10), xytext=(188.92,-10), arrowprops={'arrowstyle': '<->', 'lw': 1, 'ec': 'b', 'shrinkA': 1})
ax[1].annotate(s='', xy=(187.02,182), xytext=(188.55,182), arrowprops={'arrowstyle': '<->', 'lw': 1, 'ec': 'r', 'shrinkA': 1})
ax[1].annotate(s='', xy=(187.42,932), xytext=(188.16,932), arrowprops={'arrowstyle': '<->', 'lw': 1, 'ec': 'g', 'shrinkA': 1})

plt.text(186.8,-130,r'$\Delta f_{SB3}$',bbox=dict(facecolor='blue', alpha=0.4))
plt.text(188.6,-130,r'$\Delta f_{SB3}$',bbox=dict(facecolor='blue', alpha=0.4))

plt.text(187.15,300,r'$\Delta f_{SB2}$',bbox=dict(facecolor='red', alpha=0.4))
plt.text(188.3,300,r'$\Delta f_{SB2}$',bbox=dict(facecolor='red', alpha=0.4))

plt.text(187.5,800,r'$\Delta f_{SB1}$',bbox=dict(facecolor='green', alpha=0.4))
plt.text(187.9,800,r'$\Delta f_{SB1}$',bbox=dict(facecolor='green', alpha=0.4))
plt.scatter(187.784, -10, 50,color='b')

plt.scatter(187.784, 182, 50,color='r')
plt.scatter(187.784, 932, 50,color='g')
plt.savefig(ddir+'Plot.pdf')
# Out:
# <div id='29e7b9cc-3c56-487f-bd21-8d928103894f'></div>
# <ipython-input-38-05f7aefad358>:35: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax[1].annotate(s='', xy=(186.65,-10), xytext=(188.92,-10), arrowprops={'arrowstyle': '<->', 'lw': 1, 'ec': 'b', 'shrinkA': 1})
# <ipython-input-38-05f7aefad358>:36: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax[1].annotate(s='', xy=(187.02,182), xytext=(188.55,182), arrowprops={'arrowstyle': '<->', 'lw': 1, 'ec': 'r', 'shrinkA': 1})
# <ipython-input-38-05f7aefad358>:37: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# ...

# %%
import math
C = np.loadtxt (ddir+'Data3.txt')
d1=C[:,0]
d2=C[:,1]

#a1=42.04751 ± 6.92396
#a2=41.49475 ± 6.9864
#t1=7913.70681 ± 1939.30792
#t2=58221.74439 ± 14665.88972
#y0=7.99873 ± 1.80691

a1=42.04751 
a2=41.49475 
t1=7913.70681 
t2=58221.74439 
y0=7.99873 

def double_decay(x,a1,a2,t1,t2,y0):
    return a1*np.exp(-t1/x) + a2* np.exp(-t2/x) + y0

# %%
xnew1=np.linspace(1000,250000,500)
popt, pcov = curve_fit(double_decay, d1, d2, p0=[0, 0, 0, 0, 0], bounds=(-np.inf, np.inf))
#popt, pcov = curve_fit(double_decay, d1,d2)

fit=52.04751*np.exp(-xnew1/7913.70681)+41.49475*np.exp(-xnew1/58221.74439)

# %%
pfit1 = double_decay(xnew1,*popt)
popt
# Out:
# array([-2.75935133e+01, -5.47548352e+01,  4.68643003e+04,  5.91318048e+03,
#         8.47277327e+01])

# %%
fig,ax=plt.subplots(1,figsize=(4,4))
ax.plot(d1,d2,'ob',markersize='8',label='Efficiency for 100ms')
ax.plot(xnew1,pfit1,'-r',label='Fitting')
#ax.plot(xnew1,fit,'-k',label='Fitting')
ax.set_ylabel(r'$Effciency(\%)$')
ax.set_xlabel(r'$No\ of\ Ions$')
ax.legend()
plt.text(70000,60,r'$A \exp(-x/\tau_{1})+B \exp(-x/\tau_{2})+c$', bbox=dict(facecolor='white', alpha=0.5))
#ax.set_xlim(0,5.5)
#ax.set_ylim(0,600)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
def double_decay1(x,a1,a2,t1,t2,y0):
    return a1*np.exp(-x/t1) + a2*np.exp(-x/t2) + y0

# %%
xnew2=np.linspace(1000,250000,200)
popt2, pcov2 = curve_fit(double_decay1, d1, d2, p0=[42, 41, 7913, 58221, 7.9], bounds=(-np.inf, np.inf))

pfit2 = double_decay(xnew2,*popt2)

# %%
fig,ax=plt.subplots(1,figsize=(4,4))
ax.plot(d1,d2,'ob',markersize='8',label='Efficiency for 100ms')
#ax.plot(xnew1,pfit1,'-r',label='Fitting')
ax.plot(xnew2,pfit2,'-k',label='Fitting')
ax.set_ylabel(r'$Effciency(\%)$')
ax.set_xlabel(r'$No\ of\ Ions$')
ax.legend()
plt.text(70000,60,r'$A \exp(-x/\tau_{1})+B \exp(-x/\tau_{2})+c$', bbox=dict(facecolor='white', alpha=0.5))
#ax.set_xlim(0,5.5)
#ax.set_ylim(0,600)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
popt2[4]
# Out:
# 7.9987236658132135

# %%
x=np.linspace(1000,250000,300)
y1=popt2[0]*np.exp(-(x/popt2[2])) + popt2[1]*np.exp(-(x/popt2[3])) + popt2[4]
y2=popt2[0]*np.exp(-(popt2[2]/x)) + popt2[1]*np.exp(-(popt2[3]/x)) + popt2[4]

fig,ax=plt.subplots(1,figsize=(6,4))
ax.plot(d1,d2,'ob',markersize='8',label=r'Efficiency for 100ms')
ax.plot(x,y1,'-k',markersize='8',label=r'$y1=A \exp(-x/\tau_{1})+B \exp(-x/\tau_{2})+c$')
ax.plot(x,y2,'-r',markersize='8',label=r'$y2=A \exp(-\tau_{1}/x)+B \exp(-\tau_{2}/x)+c$')
ax.set_ylabel(r'$Effciency(\%)$')
ax.set_xlabel(r'$No\ of\ Ions$')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
ddir='C:/Users/vijay/Downloads/'
fig=plt.figure(figsize=(8, 6)) 
#plt.title(r'Normal human Lungs Analysed by Python')
#plt.Circle((1, 1), 0.02, color='r', alpha=0.5)
columns = 2
rows = 2
#name=["Lung Image","Ostu Segmentation","clear_border","Inverted_image","clear_border1","filled_image","Open_image",
      #"Parenchyma","Nodules"]
name=["(a) 0.06ms","(b) 0.64ms","(c) 1.02ms","(d) 1.85ms"]
for i in range(1, columns*rows +1):
    try:
        img = plt.imread(ddir + 'a' + str(i) + '.jpg')
    except:
        pass
    fig.add_subplot(rows, columns, i)
    plt.text(65,25,name[i-1],bbox=dict(facecolor='white', alpha=1),fontsize=10)
    plt.axis('off')
    plt.imshow(img)
    plt.tight_layout()
      
    plt.subplots_adjust(wspace=0.05, hspace=0.05)
    #fig.savefig(ddir+'Combineplot.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
x=np.loadtxt(ddir+'DBdata1.txt')
y=np.loadtxt(ddir+'DBdata2.txt')
u=np.loadtxt(ddir+'DBdata3.txt')
v=np.loadtxt(ddir+'DBdata4.txt')


fig,ax=plt.subplots(2,2,figsize=(4,3))
ax[0,0].hist(x,bins=50,color='b',label='(a) 0.06ms',lw=1, ec="black")
ax[0,0].set_xlabel(r'$Axial Position(mm)$')
ax[0,0].set_ylabel(r'$Number\ of\ Ions$')
ax[0,0].legend()

ax[0,1].hist(y,bins=50,color='r',label='(b) 0.64ms',lw=1, ec="black")
ax[0,1].set_xlabel(r'$Axial Position(mm)$')
ax[0,1].set_ylabel(r'$Number\ of\ Ions$')
ax[0,1].legend()

ax[1,0].hist(u,bins=50,color='g',label='(c) 1.02ms',lw=1, ec="black")
ax[1,0].set_xlabel(r'$Axial Position(mm)$')
ax[1,0].set_ylabel(r'$Number\ of\ Ions$')
ax[1,0].legend()

ax[1,1].hist(v,bins=50,color='m',label='(d) 1.85ms',lw=1, ec="black")
ax[1,1].set_xlabel(r'$Axial Position(mm)$')
ax[1,1].set_ylabel(r'$Number\ of\ Ions$')
ax[1,1].legend()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
x=np.loadtxt(ddir+'DBdata1.txt')
y=np.loadtxt(ddir+'DBdata2.txt')
u=np.loadtxt(ddir+'DBdata3.txt')
v=np.loadtxt(ddir+'DBdata4.txt')


fig,ax=plt.subplots(2,2,figsize=(8,6))
ax[0,0].hist(x,bins=50,color='r',label='(a) 0.06ms',lw=1, ec="black")
ax[0,0].set_xlabel(r'$Axial Position(mm)$')
ax[0,0].set_ylabel(r'$Number\ of\ Ions$')
ax[0,0].legend()

ax[0,1].hist(y,bins=50,color='r',label='(b) 0.64ms',lw=1, ec="black")
ax[0,1].set_xlabel(r'$Axial Position(mm)$')
ax[0,1].set_ylabel(r'$Number\ of\ Ions$')
ax[0,1].legend()

ax[1,0].hist(u,bins=50,color='r',label='(c) 1.02ms',lw=1, ec="black")
ax[1,0].set_xlabel(r'$Axial Position(mm)$')
ax[1,0].set_ylabel(r'$Number\ of\ Ions$')
ax[1,0].legend()

ax[1,1].hist(v,bins=50,color='r',label='(d) 1.85ms',lw=1, ec="black")
ax[1,1].set_xlabel(r'$Axial Position(mm)$')
ax[1,1].set_ylabel(r'$Number\ of\ Ions$')
ax[1,1].legend()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">
