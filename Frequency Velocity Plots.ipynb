# %%
import numpy as np
import matplotlib.pyplot as plt
from piv import*
# %matplotlib notebook
plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["mathtext.fontset"] = 'cm'
plt.rcParams["axes.labelsize"] = '13'
plt.rcParams['xtick.major.size'] = '3'
plt.rcParams['grid.alpha'] = '0.5'
plt.rcParams['legend.fontsize'] = '11'
plt.rcParams['errorbar.capsize'] = '2.5'
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['xtick.labelsize'] = '12'
plt.rcParams['ytick.labelsize'] = '12'
plt.rcParams['text.usetex'] = False #True
plt.rcParams["legend.loc"] = 'upper right'
plt.rcParams['lines.markersize'] = 10
plt.rcParams['xtick.direction'] ='in'
plt.rcParams['ytick.direction'] ='in'
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
shapes = ['o', 'X', 's', 'd', 'v', '^']

# %%
fbIn47=np.loadtxt('E:/Vijay/Velocity_Data/47%data.txt')
Wi47=fbIn47[:,0][1::]
fu47=fbIn47[:,1][1::]
Iu47=fbIn47[:,2][1::]
fv47=fbIn47[:,3][1::]
Iv47=fbIn47[:,4][1::]
cu47=fbIn47[:,5][1::]
cv47=fbIn47[:,6][1::]
ku47=fbIn47[:,7][1::]
kv47=fbIn47[:,8][1::]


fbIn60=np.loadtxt('E:/Vijay/Velocity_Data/60%data.txt')
Wi60=fbIn60[:,0]
fu60=fbIn60[:,1]
Iu60=fbIn60[:,2]
fv60=fbIn60[:,3]
Iv60=fbIn60[:,4]
cu60=fbIn60[:,5]
cv60=fbIn60[:,6]
ku60=fbIn60[:,7]
kv60=fbIn60[:,8]

fbIn65=np.loadtxt('E:/Vijay/Velocity_Data/65%data.txt')
Wi65=fbIn65[:,0]
fu65=fbIn65[:,1]
Iu65=fbIn65[:,2]
fv65=fbIn65[:,3]
Iv65=fbIn65[:,4]
cu65=fbIn65[:,5]*1000
cv65=fbIn65[:,6]*1000
ku65=fbIn65[:,7]
kv65=fbIn65[:,8]

El25=11
El47=304
El60=11232
El65=28251


fig,ax=plt.subplots(2,2,figsize=(8,6))
ax[0,0].loglog(Wi47,fu47,'-or',markersize=10, label='%d'%El47)
ax[0,0].loglog(Wi60,fu60,'-og',markersize=10, label='%d'%El60)
ax[0,0].loglog(Wi65,fu65,'-ok',markersize=10, label='%d'%El65)
#ax[0,0].loglog(Wi47,fv47,'ob',markersize=10, label=r'$Span$')
ax[0,0].set_ylim(0.01,100)
ax[0,0].set_xlim(50,3000)
ax[0,0].set_ylabel(r'$f_{u}\, (Hz)$')
ax[0,0].legend()

ax[0,1].loglog(Wi47,Iu47,'-or',markersize=10,label='%d'%El47)
ax[0,1].loglog(Wi60,Iu60,'-og',markersize=10,label='%d'%El60)
ax[0,1].loglog(Wi65,Iu65,'-ok',markersize=10,label='%d'%El65)
#ax[0,1].loglog(Wi47,Iv47,'ob',markersize=10,label=r'$Span$')
ax[0,1].set_ylabel(r'$I_{u}\,(a.u)$')
#ax[0,1].set_xlabel(r'$Wi$')
ax[0,1].set_ylim(0.001,1)
ax[0,1].set_xlim(50,3000)
ax[0,1].legend()

ax[1,0].loglog(Wi47,cu47,'-or',markersize=10, label='%d'%El47)
ax[1,0].loglog(Wi60,cu60,'-og',markersize=10, label='%d'%El60)
ax[1,0].loglog(Wi65,cu65,'-ok',markersize=10, label='%d'%El65)
#ax[1,0].loglog(Wi47,cv47,'ob',markersize=10, label=r'$Span$')
ax[1,0].set_ylabel(r'$C_{u}\,(mm/s)$')
ax[1,0].set_xlabel(r'$Wi$')
ax[1,0].set_ylim(0.01,300)
ax[1,0].set_xlim(50,3000)
ax[1,0].legend()

ax[1,1].loglog(Wi47,ku47,'-or',markersize=10, label='%d'%El47)
ax[1,1].loglog(Wi60,ku60,'-og',markersize=10, label='%d'%El60)
ax[1,1].loglog(Wi65,ku65,'-ok',markersize=10, label='%d'%El65)
#ax[1,1].loglog(Wi47,kv47,'ob',markersize=10,label=r'$Span$')
ax[1,1].set_ylabel(r'$K_{u}(mm^{-1})$')
ax[1,1].set_xlabel(r'$Wi$')
#ax[1,1].set_ylim(0.01,100)
#ax[1,1].set_xlim(50,3000)
ax[1,1].legend()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
ax[1,0].set_xlim(50,3000)
# Out:
# (50, 3000)

# %%
fbIn25=np.loadtxt('E:/Vijay/Velocity_Data/25%data.txt')
Wi25=fbIn25[:,0][1::]
Re25=fbIn25[:,1][1::]
fu25=fbIn25[:,2][1::]
Iu25=fbIn25[:,3][1::]
fv25=fbIn25[:,4][1::]
Iv25=fbIn25[:,5][1::]
cu25=fbIn25[:,6][1::]*1000
cv25=fbIn25[:,7][1::]*1000
ku25=fbIn25[:,8][1::]
kv25=fbIn25[:,9][1::]

fbIn47=np.loadtxt('E:/Vijay/Velocity_Data/47%data.txt')
Wi47=fbIn47[:,0][1::]
fu47=fbIn47[:,1][1::]
Iu47=fbIn47[:,2][1::]
fv47=fbIn47[:,3][1::]
Iv47=fbIn47[:,4][1::]
cu47=fbIn47[:,5][1::]
cv47=fbIn47[:,6][1::]
ku47=fbIn47[:,7][1::]
kv47=fbIn47[:,8][1::]


fbIn60=np.loadtxt('E:/Vijay/Velocity_Data/60%data.txt')
Wi60=fbIn60[:,0]
fu60=fbIn60[:,1]
Iu60=fbIn60[:,2]
fv60=fbIn60[:,3]
Iv60=fbIn60[:,4]
cu60=fbIn60[:,5]
cv60=fbIn60[:,6]
ku60=fbIn60[:,7]
kv60=fbIn60[:,8]

fbIn65=np.loadtxt('E:/Vijay/Velocity_Data/65%data.txt')
Wi65=fbIn65[:,0]
fu65=fbIn65[:,1]
Iu65=fbIn65[:,2]
fv65=fbIn65[:,3]
Iv65=fbIn65[:,4]
cu65=fbIn65[:,5]*1000
cv65=fbIn65[:,6]*1000
ku65=fbIn65[:,7]
kv65=fbIn65[:,8]



fig,ax=plt.subplots(2,2,figsize=(8,6))
ax[0,0].loglog(Wi25,fv25,'-or',markersize=10, label='%d'%El25)
ax[0,0].loglog(Wi47,fv47,'-og',markersize=10, label='%d'%El47)
ax[0,0].loglog(Wi60,fv60,'-ob',markersize=10, label='%d'%El60)
ax[0,0].loglog(Wi65,smooth(fv65,5),'-ok',markersize=10, label='%d'%El65)
#ax[0,0].loglog(Wi47,fv47,'ob',markersize=10, label=r'$Span$')
ax[0,0].set_ylabel(r'$f_{v}\, (Hz)$')
ax[0,0].set_ylim(0.01,100)
#ax[0,0].legend()

ax[0,1].loglog(Wi25,Iv25,'-or',markersize=10,label='%d'%El25)
ax[0,1].loglog(Wi47,Iv47,'-og',markersize=10,label='%d'%El47)
ax[0,1].loglog(Wi60,Iv60,'-ob',markersize=10,label='%d'%El60)
ax[0,1].loglog(Wi65,Iv65,'-ok',markersize=10,label='%d'%El65)
#ax[0,1].loglog(Wi47,Iv47,'ob',markersize=10,label=r'$Span$')
ax[0,1].set_ylabel(r'$I_{v}\,(a.u)$')
ax[0,1].set_xlabel(r'$Wi$')
ax[0,1].set_ylim(0.001,1)
#ax[0,1].set_xlim(50,2000)
#ax[0,1].legend()

ax[1,0].loglog(Wi25,cv25,'-or',markersize=10, label='%d'%El25)
ax[1,0].loglog(Wi47,cv47,'-og',markersize=10, label='%d'%El47)
ax[1,0].loglog(Wi60,cv60,'-ob',markersize=10, label='%d'%El60)
ax[1,0].loglog(Wi65,cv65,'-ok',markersize=10, label='%d'%El65)
#ax[1,0].loglog(Wi47,cv47,'ob',markersize=10, label=r'$Span$')
ax[1,0].set_ylabel(r'$C_{v}\,(mm/s)$')
#ax[1,0].set_ylim(0.01,300)
#ax[1,0].legend()

ax[1,1].loglog(Wi25,kv25,'-or',markersize=10,label='%d'%El25)
ax[1,1].loglog(Wi47,kv47,'-og',markersize=10,label='%d'%El47)
ax[1,1].loglog(Wi60,kv60,'-ob',markersize=10,label='%d'%El60)
ax[1,1].loglog(Wi65,kv65,'-ok',markersize=10,label='%d'%El65)
#ax[1,1].loglog(Wi47,kv47,'ob',markersize=10,label=r'$Span$')
ax[1,1].set_ylabel(r'$K_{v}(mm^{-1})$')
ax[1,1].set_xlabel(r'$Wi$')
ax[1,1].set_ylim(0.1,100)
#ax[1,1].set_xlim(50,2000)
#ax[1,1].legend()
#plt.rcParams.update({'font.size': 40})
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
Freq=[Wi25[4::],fv25[4::],Wi47[4::],fv47[4::],Wi60[4::],fv60[4::],Wi65[7:25],fv65[7:25]]

Freq
# Out:
# [array([201., 234., 255., 258., 357., 497., 776.]),
#  array([12.2, 14.2, 14.5, 20.6, 34.2, 37.3, 32.8]),
#  array([ 190.,  265.,  308.,  355.,  415.,  457.,  496.,  611.,  709.,
#          888., 1390., 2000., 2690., 3260., 3260., 3260.]),
#  array([ 1.483,  1.96 ,  1.687,  2.28 ,  2.269,  2.95 ,  3.73 ,  3.59 ,
#          6.51 ,  6.47 ,  7.5  ,  9.7  , 22.3  , 55.43 , 61.16 , 58.46 ]),
#  array([ 372.,  422.,  497.,  555.,  634.,  748.,  888., 1030., 1160.,
#         1700., 2190., 3060., 3860., 4840., 6200., 8260.]),
#  array([ 1.18,  1.2 ,  1.33,  1.35,  1.42,  1.58,  1.61,  2.02,  2.28,
#          2.79,  5.25,  6.47,  8.2 , 11.7 , 19.9 , 46.8 ]),
#  array([ 214.7788513,  244.7624066,  266.8467663,  277.7634858,
#          314.4568739,  329.6497886,  360.532991 ,  363.4915303,
#          422.2347789,  504.1228396,  522.137814 ,  599.2179071,
#          599.7378244,  699.863567 ,  719.1864808,  963.2393394,
#         1002.526071 , 1004.06687  ]),
# ...

# %%
Wi_25=Freq[0]
fv_25=Freq[1]
Wi_47=Freq[2]
fv_47=Freq[3]
Wi_60=Freq[4]
fv_60=Freq[5]
Wi_65=Freq[6]
fv_65=Freq[7]
fig,ax=plt.subplots(1,figsize=(6,6))
ax.loglog(Wi_25,fv_25,'-or',markersize=12, label='%d'%El25)
ax.loglog(Wi_47,fv_47,'-og',markersize=12, label='%d'%El47)
ax.loglog(Wi_60,fv_60,'-ob',markersize=12, label='%d'%El60)
ax.loglog(Wi_65,fv_65,'-ok',markersize=12, label='%d'%El65)
ax.set_ylabel(r'$f_{v}\, (Hz)$') 
ax.set_xlabel(r'$Wi$')
ax.set_ylim(0.1,400)
ax.set_xlim(100,9000)
ax.legend()
plt.savefig('fv_Wi.pdf')
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %%
fbIn25=np.loadtxt('E:/Vijay/Velocity_Data/25%data.txt')
Wi25=fbIn25[:,0][1::]
Re25=fbIn25[:,1][1::]
fu25=fbIn25[:,2][1::]
Iu25=fbIn25[:,3][1::]
fv25=fbIn25[:,4][1::]
Iv25=fbIn25[:,5][1::]
cu25=fbIn25[:,6][1::]*1000
cv25=fbIn25[:,7][1::]*1000
ku25=fbIn25[:,8][1::]
kv25=fbIn25[:,9][1::]

fbIn47=np.loadtxt('E:/Vijay/Velocity_Data/47%data.txt')
Wi47=fbIn47[:,0][1::]
fu47=fbIn47[:,1][1::]
Iu47=fbIn47[:,2][1::]
fv47=fbIn47[:,3][1::]
Iv47=fbIn47[:,4][1::]
cu47=fbIn47[:,5][1::]
cv47=fbIn47[:,6][1::]
ku47=fbIn47[:,7][1::]
kv47=fbIn47[:,8][1::]


fbIn60=np.loadtxt('E:/Vijay/Velocity_Data/60%data.txt')
Wi60=fbIn60[:,0]
fu60=fbIn60[:,1]
Iu60=fbIn60[:,2]
fv60=fbIn60[:,3]
Iv60=fbIn60[:,4]
cu60=fbIn60[:,5]
cv60=fbIn60[:,6]
ku60=fbIn60[:,7]
kv60=fbIn60[:,8]

fbIn65=np.loadtxt('E:/Vijay/Velocity_Data/65%data.txt')
Wi65=fbIn65[:,0]
fu65=fbIn65[:,1]
Iu65=fbIn65[:,2]
fv65=fbIn65[:,3]
Iv65=fbIn65[:,4]
cu65=fbIn65[:,5]*1000
cv65=fbIn65[:,6]*1000
ku65=fbIn65[:,7]
kv65=fbIn65[:,8]



fig,ax=plt.subplots(4,4,figsize=(8,6))
ax[0,0].loglog(Wi25,fu25,'-or',markersize=10, label='%d'%El47)
ax[0,0].loglog(Wi47,fu47,'-og',markersize=10, label='%d'%El47)
ax[0,0].loglog(Wi60,fu60,'-ob',markersize=10, label='%d'%El60)
ax[0,0].loglog(Wi65,fu65,'-ok',markersize=10, label='%d'%El65)
#ax[0,0].loglog(Wi47,fv47,'ob',markersize=10, label=r'$Span$')
ax[0,0].set_ylabel(r'$f_{u}\, (Hz)$')
ax[0,0].set_ylim(0.01,100)
#ax[0,0].legend()

ax[0,1].loglog(Wi25,Iu25,'-or',markersize=10,label='%d'%El47)
ax[0,1].loglog(Wi47,Iu47,'-og',markersize=10,label='%d'%El47)
ax[0,1].loglog(Wi60,Iu60,'-ob',markersize=10,label='%d'%El60)
ax[0,1].loglog(Wi65,Iu65,'-ok',markersize=10,label='%d'%El65)
#ax[0,1].loglog(Wi47,Iv47,'ob',markersize=10,label=r'$Span$')
ax[0,1].set_ylabel(r'$I_{u}\,(a.u)$')
ax[0,1].set_xlabel(r'$Wi$')
ax[0,1].set_ylim(0.001,1)
#ax[0,1].set_xlim(50,2000)
ax[0,1].legend()

ax[1,0].loglog(Wi25,cu25,'-or',markersize=10, label='%d'%El47)
ax[1,0].loglog(Wi47,cu47,'-og',markersize=10, label='%d'%El47)
ax[1,0].loglog(Wi60,cu60,'-ob',markersize=10, label='%d'%El60)
ax[1,0].loglog(Wi65,cu65,'-ok',markersize=10, label='%d'%El65)
#ax[1,0].loglog(Wi47,cv47,'ob',markersize=10, label=r'$Span$')
ax[1,0].set_ylabel(r'$C_{u}\,(mm/s)$')
#ax[1,0].set_ylim(0.01,300)
#ax[1,0].legend()

ax[1,1].loglog(Wi25,ku25,'-or',markersize=10,label='%d'%El47)
ax[1,1].loglog(Wi47,ku47,'-og',markersize=10,label='%d'%El47)
ax[1,1].loglog(Wi60,ku60,'-ob',markersize=10,label='%d'%El60)
ax[1,1].loglog(Wi65,ku65,'-ok',markersize=10,label='%d'%El65)
#ax[1,1].loglog(Wi47,kv47,'ob',markersize=10,label=r'$Span$')
ax[1,1].set_ylabel(r'$K_{u}(mm^{-1})$')
ax[1,1].set_xlabel(r'$Wi$')
ax[1,1].set_ylim(0.01,100)
#ax[1,1].set_xlim(50,2000)
#ax[1,1].legend()
#plt.rcParams.update({'font.size': 40})
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
fbIn25=np.loadtxt('E:/Vijay/Velocity_Data/25%data.txt')
Wi25=fbIn25[:,0][1::]
Re25=fbIn25[:,1][1::]
fu25=fbIn25[:,2][1::]
Iu25=fbIn25[:,3][1::]
fv25=fbIn25[:,4][1::]
Iv25=fbIn25[:,5][1::]
cu25=fbIn25[:,6][1::]*1000
cv25=fbIn25[:,7][1::]*1000
ku25=fbIn25[:,8][1::]
kv25=fbIn25[:,9][1::]

fbIn47=np.loadtxt('E:/Vijay/Velocity_Data/47%data.txt')
Wi47=fbIn47[:,0][1::]
fu47=fbIn47[:,1][1::]
Iu47=fbIn47[:,2][1::]
fv47=fbIn47[:,3][1::]
Iv47=fbIn47[:,4][1::]
cu47=fbIn47[:,5][1::]
cv47=fbIn47[:,6][1::]
ku47=fbIn47[:,7][1::]
kv47=fbIn47[:,8][1::]


fbIn60=np.loadtxt('E:/Vijay/Velocity_Data/60%data.txt')
Wi60=fbIn60[:,0]
fu60=fbIn60[:,1]
Iu60=fbIn60[:,2]
fv60=fbIn60[:,3]
Iv60=fbIn60[:,4]
cu60=fbIn60[:,5]
cv60=fbIn60[:,6]
ku60=fbIn60[:,7]
kv60=fbIn60[:,8]

fbIn65=np.loadtxt('E:/Vijay/Velocity_Data/65%data.txt')
Wi65=fbIn65[:,0]
fu65=fbIn65[:,1]
Iu65=fbIn65[:,2]
fv65=fbIn65[:,3]
Iv65=fbIn65[:,4]
cu65=fbIn65[:,5]*1000
cv65=fbIn65[:,6]*1000
ku65=fbIn65[:,7]
kv65=fbIn65[:,8]



fig,ax=plt.subplots(2,2,figsize=(8,6))
ax[0,0].plot(Wi25,fv25,'-or',markersize=10, label='%d'%El47)
ax[0,0].plot(Wi47,fv47,'-og',markersize=10, label='%d'%El47)
ax[0,0].plot(Wi60,fv60,'-ob',markersize=10, label='%d'%El60)
ax[0,0].plot(Wi65,fv65,'-ok',markersize=10, label='%d'%El65)
#ax[0,0].loglog(Wi47,fv47,'ob',markersize=10, label=r'$Span$')
ax[0,0].set_ylabel(r'$f_{v}\, (Hz)$')
#ax[0,0].set_ylim(0.01,100)
#ax[0,0].legend()

ax[0,1].plot(Wi25,Iv25,'-or',markersize=10,label='%d'%El47)
ax[0,1].plot(Wi47,Iv47,'-og',markersize=10,label='%d'%El47)
ax[0,1].plot(Wi60,Iv60,'-ob',markersize=10,label='%d'%El60)
ax[0,1].plot(Wi65,Iv65,'-ok',markersize=10,label='%d'%El65)
#ax[0,1].loglog(Wi47,Iv47,'ob',markersize=10,label=r'$Span$')
ax[0,1].set_ylabel(r'$I_{v}\,(a.u)$')
ax[0,1].set_xlabel(r'$Wi$')
#ax[0,1].set_ylim(0.001,1)
#ax[0,1].set_xlim(50,2000)
#ax[0,1].legend()

ax[1,0].plot(Wi25,cv25,'-or',markersize=10, label='%d'%El47)
ax[1,0].plot(Wi47,cv47,'-og',markersize=10, label='%d'%El47)
ax[1,0].plot(Wi60,cv60,'-ob',markersize=10, label='%d'%El60)
ax[1,0].plot(Wi65,cv65,'-ok',markersize=10, label='%d'%El65)
#ax[1,0].loglog(Wi47,cv47,'ob',markersize=10, label=r'$Span$')
ax[1,0].set_ylabel(r'$C_{v}\,(mm/s)$')
#ax[1,0].set_ylim(0.01,300)
#ax[1,0].legend()

ax[1,1].plot(Wi25,kv25,'-or',markersize=10,label='%d'%El47)
ax[1,1].plot(Wi47,kv47,'-og',markersize=10,label='%d'%El47)
ax[1,1].plot(Wi60,kv60,'-ob',markersize=10,label='%d'%El60)
ax[1,1].plot(Wi65,kv65,'-ok',markersize=10,label='%d'%El65)
#ax[1,1].loglog(Wi47,kv47,'ob',markersize=10,label=r'$Span$')
ax[1,1].set_ylabel(r'$K_{v}(mm^{-1})$')
ax[1,1].set_xlabel(r'$Wi$')
#ax[1,1].set_ylim(0.1,100)
#ax[1,1].set_xlim(50,2000)
#ax[1,1].legend()
#plt.rcParams.update({'font.size': 40})
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
Wi25=Wi25[4:13]
Iv25=Iv25[4:13]

Wi47=Wi47[5:13]
Iv47=Iv47[5:13]

Wi60=Wi60[5:13]
Iv60=Iv60[5:13]

Wi65=Wi65[2:20]
Iv65=Iv65[2:20]

fig,ax=plt.subplots(1)
#ax.plot(Wi25,Iv25,'-or',markersize=10,label='%d'%El47)
#ax.plot(Wi47,Iv47,'-og',markersize=10,label='%d'%El47)
#ax.plot(Wi60,Iv60,'-ob',markersize=10,label='%d'%El60)
ax.plot(Wi65,Iv65,'-ok',markersize=10,label='%d'%El65)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fbIn25=np.loadtxt('E:/Vijay/Velocity_Data/25%data.txt')
Wi25=fbIn25[:,0][1::]
Re25=fbIn25[:,1][1::]
fu25=fbIn25[:,2][1::]
Iu25=fbIn25[:,3][1::]
fv25=fbIn25[:,4][1::]
Iv25=fbIn25[:,5][1::]
cu25=fbIn25[:,6][1::]*1000
cv25=fbIn25[:,7][1::]*1000
ku25=fbIn25[:,8][1::]
kv25=fbIn25[:,9][1::]

fbIn47=np.loadtxt('E:/Vijay/Velocity_Data/47%data.txt')
Wi47=fbIn47[:,0][1::]
fu47=fbIn47[:,1][1::]
Iu47=fbIn47[:,2][1::]
fv47=fbIn47[:,3][1::]
Iv47=fbIn47[:,4][1::]
cu47=fbIn47[:,5][1::]
cv47=fbIn47[:,6][1::]
ku47=fbIn47[:,7][1::]
kv47=fbIn47[:,8][1::]


fbIn60=np.loadtxt('E:/Vijay/Velocity_Data/60%data.txt')
Wi60=fbIn60[:,0]
fu60=fbIn60[:,1]
Iu60=fbIn60[:,2]
fv60=fbIn60[:,3]
Iv60=fbIn60[:,4]
cu60=fbIn60[:,5]
cv60=fbIn60[:,6]
ku60=fbIn60[:,7]
kv60=fbIn60[:,8]

fbIn65=np.loadtxt('E:/Vijay/Velocity_Data/65%data.txt')
Wi65=fbIn65[:,0]
fu65=fbIn65[:,1]
Iu65=fbIn65[:,2]
fv65=fbIn65[:,3]
Iv65=fbIn65[:,4]
cu65=fbIn65[:,5]*1000
cv65=fbIn65[:,6]*1000
ku65=fbIn65[:,7]
kv65=fbIn65[:,8]
El25=11
El47=304
El60=11232
El65=28251


fig,ax=plt.subplots(2,2,figsize=(8,6))
ax[0,0].plot(Wi47,fu47,'-or',markersize=10, label='%d'%El47)
ax[0,0].plot(Wi60,fu60,'-og',markersize=10, label='%d'%El60)
ax[0,0].plot(Wi65,fu65,'-ok',markersize=10, label='%d'%El65)
#ax[0,0].loglog(Wi47,fv47,'ob',markersize=10, label=r'$Span$')
#ax[0,0].set_ylim(0,2)
#ax[0,0].set_xlim(0,1000)
ax[0,0].set_ylabel(r'$f_{u}\, (Hz)$')
ax[0,0].legend()

ax[0,1].plot(Wi47,Iu47,'-or',markersize=10,label='%d'%El47)
ax[0,1].plot(Wi60,Iu60,'-og',markersize=10,label='%d'%El60)
ax[0,1].plot(Wi65,Iu65,'-ok',markersize=10,label='%d'%El65)
#ax[0,1].loglog(Wi47,Iv47,'ob',markersize=10,label=r'$Span$')
ax[0,1].set_ylabel(r'$I_{u}\,(a.u)$')
#ax[0,1].set_xlabel(r'$Wi$')
#ax[0,1].set_ylim(0,50)
ax[0,1].set_xlim(0,1000)
ax[0,1].legend()

ax[1,0].plot(Wi47,cu47,'-or',markersize=10, label='%d'%El47)
ax[1,0].plot(Wi60,cu60,'-og',markersize=10, label='%d'%El60)
ax[1,0].plot(Wi65,cu65,'-ok',markersize=10, label='%d'%El65)
#ax[1,0].loglog(Wi47,cv47,'ob',markersize=10, label=r'$Span$')
ax[1,0].set_ylabel(r'$C_{u}\,(mm/s)$')
ax[1,0].set_xlabel(r'$Wi$')
ax[1,0].set_ylim(0,5)
ax[1,0].set_xlim(0,1000)
ax[1,0].legend()

ax[1,1].plot(Wi47,ku47,'-or',markersize=10, label='%d'%El47)
ax[1,1].plot(Wi60,ku60,'-og',markersize=10, label='%d'%El60)
ax[1,1].plot(Wi65,ku65,'-ok',markersize=10, label='%d'%El65)
#ax[1,1].loglog(Wi47,kv47,'ob',markersize=10,label=r'$Span$')
ax[1,1].set_ylabel(r'$K_{u}(mm^{-1})$')
ax[1,1].set_xlabel(r'$Wi$')
ax[1,1].set_ylim(0.01,100)
ax[1,1].set_xlim(0,1000)
ax[1,1].legend()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
fbIn47=np.loadtxt('E:/Vijay/Velocity_Data/47%data.txt')
Wi47=fbIn47[:,0][1::]
fu47=fbIn47[:,1][1::]
Iu47=fbIn47[:,2][1::]
fv47=fbIn47[:,3][1::]
Iv47=fbIn47[:,4][1::]
cu47=fbIn47[:,5][1::]
cv47=fbIn47[:,6][1::]
ku47=fbIn47[:,7][1::]
kv47=fbIn47[:,8][1::]


fbIn60=np.loadtxt('E:/Vijay/Velocity_Data/60%data.txt')
Wi60=fbIn60[:,0]
fu60=fbIn60[:,1]
Iu60=fbIn60[:,2]
fv60=fbIn60[:,3]
Iv60=fbIn60[:,4]
cu60=fbIn60[:,5]
cv60=fbIn60[:,6]
ku60=fbIn60[:,7]
kv60=fbIn60[:,8]

fbIn65=np.loadtxt('E:/Vijay/Velocity_Data/65%data.txt')
Wi65=fbIn65[:,0]
fu65=fbIn65[:,1]
Iu65=fbIn65[:,2]
fv65=fbIn65[:,3]
Iv65=fbIn65[:,4]
cu65=fbIn65[:,5]*1000
cv65=fbIn65[:,6]*1000
ku65=fbIn65[:,7]
kv65=fbIn65[:,8]



fig,ax=plt.subplots(2,2,figsize=(8,6))
ax[0,0].plot(Wi47,fv47,'-or',markersize=10, label='%d'%El47)
ax[0,0].plot(Wi60,fv60,'-og',markersize=10, label='%d'%El60)
ax[0,0].plot(Wi65,fv65,'-ok',markersize=10, label='%d'%El65)
#ax[0,0].loglog(Wi47,fv47,'ob',markersize=10, label=r'$Span$')
ax[0,0].set_ylabel(r'$f_{v}\, (Hz)$')
ax[0,0].set_ylim(0,2)
ax[0,0].set_xlim(0,1000)
ax[0,0].legend()

ax[0,1].plot(Wi47,Iv47,'-or',markersize=10,label='%d'%El47)
ax[0,1].plot(Wi60,Iv60,'-og',markersize=10,label='%d'%El60)
ax[0,1].plot(Wi65,Iv65,'-ok',markersize=10,label='%d'%El65)
#ax[0,1].loglog(Wi47,Iv47,'ob',markersize=10,label=r'$Span$')
ax[0,1].set_ylabel(r'$I_{v}\,(a.u)$')
ax[0,1].set_xlabel(r'$Wi$')
ax[0,1].set_ylim(0.001,0.1)
ax[0,1].set_xlim(0,1000)
ax[0,1].legend()

ax[1,0].plot(Wi47,cv47,'-or',markersize=10, label='%d'%El47)
ax[1,0].plot(Wi60,cv60,'-og',markersize=10, label='%d'%El60)
ax[1,0].plot(Wi65,cv65,'-ok',markersize=10, label='%d'%El65)
#ax[1,0].loglog(Wi47,cv47,'ob',markersize=10, label=r'$Span$')
ax[1,0].set_ylabel(r'$C_{v}\,(mm/s)$')
ax[1,0].set_ylim(0,3)
ax[1,0].set_xlim(0,1000)
ax[1,0].legend()

ax[1,1].plot(Wi47,kv47,'-or',markersize=10,label='%d'%El47)
ax[1,1].plot(Wi60,kv60,'-og',markersize=10,label='%d'%El60)
ax[1,1].plot(Wi65,kv65,'-ok',markersize=10,label='%d'%El65)
#ax[1,1].loglog(Wi47,kv47,'ob',markersize=10,label=r'$Span$')
ax[1,1].set_ylabel(r'$K_{v}(mm^{-1})$')
ax[1,1].set_xlabel(r'$Wi$')
ax[1,1].set_ylim(0.1,8)
ax[1,1].set_xlim(0,1000)
ax[1,1].legend()
#plt.rcParams.update({'font.size': 40})
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
import numpy as np
from scipy import sparse
from scipy.sparse.linalg import spsolve
def baseline_als(y, lam, p, niter=10):                                                                        

    s  = len(y)                                                                                               
    # assemble difference matrix                                                                              
    D0 = sparse.eye( s )                                                                                      
    d1 = [np.ones( s-1 ) * -2]                                                                             
    D1 = sparse.diags( d1, [-1] )                                                                             
    d2 = [ np.ones( s-2 ) * 1]                                                                             
    D2 = sparse.diags( d2, [-2] )                                                                             

    D  = D0 + D2 + D1                                                                                         
    w  = np.ones( s )                                                                                         
    for i in range( niter ):                                                                                  
        W = sparse.diags( [w], [0] )                                                                          
        Z =  W + lam*D.dot( D.transpose() )                                                                   
        z = spsolve( Z, w*y )                                                                                 
        w = p * (y > z) + (1-p) * (y < z)                                                                     

    return z

# %%
fbIn25=np.loadtxt('E:/Vijay/Velocity_Data/25%data.txt')
Wi25=fbIn25[:,0][1::]
Re25=fbIn25[:,1][1::]
fu25=fbIn25[:,2][1::]
Iu25=fbIn25[:,3][1::]
fv25=fbIn25[:,4][1::]
Iv25=fbIn25[:,5][1::]
cu25=fbIn25[:,6][1::]*1000
cv25=fbIn25[:,7][1::]*1000
ku25=fbIn25[:,8][1::]
kv25=fbIn25[:,9][1::]

fbIn47=np.loadtxt('E:/Vijay/Velocity_Data/47%data.txt')
Wi47=fbIn47[:,0][1::]
fu47=fbIn47[:,1][1::]
Iu47=fbIn47[:,2][1::]
fv47=fbIn47[:,3][1::]
Iv47=fbIn47[:,4][1::]
cu47=fbIn47[:,5][1::]
cv47=fbIn47[:,6][1::]
ku47=fbIn47[:,7][1::]
kv47=fbIn47[:,8][1::]


fbIn60=np.loadtxt('E:/Vijay/Velocity_Data/60%data.txt')
Wi60=fbIn60[:,0]
fu60=fbIn60[:,1]
Iu60=fbIn60[:,2]
fv60=fbIn60[:,3]
Iv60=fbIn60[:,4]
cu60=fbIn60[:,5]
cv60=fbIn60[:,6]
ku60=fbIn60[:,7]
kv60=fbIn60[:,8]

fbIn65=np.loadtxt('E:/Vijay/Velocity_Data/65%data.txt')
Wi65=fbIn65[:,0]
fu65=fbIn65[:,1]
Iu65=fbIn65[:,2]
fv65=fbIn65[:,3]
Iv65=fbIn65[:,4]
cu65=fbIn65[:,5]*1000
cv65=fbIn65[:,6]*1000
ku65=fbIn65[:,7]
kv65=fbIn65[:,8]



fig,ax=plt.subplots(4,4,figsize=(8,6))
ax[0,0].loglog(Wi25,cu25,'-or',markersize=10, label='%d'%El25)
ax[0,1].loglog(Wi25,cv25,'-or',markersize=10, label='%d'%El25)
ax[0,2].loglog(Wi25,ku25,'-or',markersize=10, label='%d'%El25)
ax[0,3].loglog(Wi25,kv25,'-or',markersize=10, label='%d'%El25)

ax[0,0].set_ylabel(r'$C_{u}\,(mm/s)$')
ax[0,1].set_ylabel(r'$C_{v}\,(mm/s)$')
ax[0,2].set_ylabel(r'$K_{u}\,(mm^-1)$')
ax[0,3].set_ylabel(r'$K_{v}\,(mm^-1)$')


ax[1,0].legend()

ax[1,0].loglog(Wi47,cu47,'-og',markersize=10, label='%d'%El47)
ax[1,1].loglog(Wi47,cv47,'-og',markersize=10, label='%d'%El47)
ax[1,2].loglog(Wi47,ku47,'-og',markersize=10, label='%d'%El47)
ax[1,3].loglog(Wi47,kv47,'-og',markersize=10, label='%d'%El47)

ax[1,0].set_ylabel(r'$C_{u}\,(mm/s)$')
ax[1,1].set_ylabel(r'$C_{v}\,(mm/s)$')
ax[1,2].set_ylabel(r'$K_{u}\,(mm^-1)$')
ax[1,3].set_ylabel(r'$K_{v}\,(mm^-1)$')


ax[2,0].loglog(Wi60,cu60,'-ob',markersize=10, label='%d'%El47)
ax[2,1].loglog(Wi60,cv60,'-ob',markersize=10, label='%d'%El47)
ax[2,2].loglog(Wi60,ku60,'-ob',markersize=10, label='%d'%El47)
ax[2,3].loglog(Wi60,kv60,'-ob',markersize=10, label='%d'%El47)

ax[2,0].set_ylabel(r'$C_{u}\,(mm/s)$')
ax[2,1].set_ylabel(r'$C_{v}\,(mm/s)$')
ax[2,2].set_ylabel(r'$K_{u}\,(mm^-1)$')
ax[2,3].set_ylabel(r'$K_{v}\,(mm^-1)$')

ax[3,0].loglog(Wi65,cu65,'-ok',markersize=10, label='%d'%El47)
ax[3,1].loglog(Wi65,cv65,'-ok',markersize=10, label='%d'%El47)
ax[3,2].loglog(Wi65,ku65,'-ok',markersize=10, label='%d'%El47)
ax[3,3].loglog(Wi65,kv65,'-ok',markersize=10, label='%d'%El47)

ax[3,0].set_ylabel(r'$C_{u}\,(mm/s)$')
ax[3,1].set_ylabel(r'$C_{v}\,(mm/s)$')
ax[3,2].set_ylabel(r'$K_{u}\,(mm^-1)$')
ax[3,3].set_ylabel(r'$K_{v}\,(mm^-1)$')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# No handles with labels found to put in legend.

# %%
fig,ax=plt.subplots(1,figsize=(4,6))
ax.loglog(Wi65[7:22],cv65[7:22],'-or',markersize=10, label='%d'%El65)
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
El65=np.loadtxt('E:/Vijay/65/vspectra/Analysis/u1.txt')
x=El65[:,0][11:4000]
y=El65[:,1][11:4000]
y1=baseline_als(y,107,0.001)
dy=y-y1
fig,ax=plt.subplots(2)
ax[0].loglog(x,y)
ax[0].loglog(x,y1)
ax[1].loglog(x,dy)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
